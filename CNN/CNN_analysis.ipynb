# %% [markdown]
# # **Skin Cancer Classification CNN Analysis**

# %% [markdown]
# ##**Importing the Libraries Required**

# %%
import torch
from torch import nn, optim
from torch.optim import Adam
from torch.utils.data import random_split, DataLoader, Dataset
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from torch.optim.lr_scheduler import ReduceLROnPlateau
from tqdm import tqdm
import pyarrow.parquet as pq
import pandas as pd
import io
from torchvision import transforms
from PIL import Image
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import random
import os

# %%
from google.colab import drive

drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %% [markdown]
# ##**Setting Library Seeds for Reproducibility**

# %%
def seed_everything(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True

# %%
seed_everything(464)

# %% [markdown]
# ##**Preparing the Dataset**

# %%
# !unzip -oq /content/drive/MyDrive/cancer_dataset.zip

# %% [markdown]
# ##**Implementing a Custom Dataset**

# %%
class CancerDataset(Dataset):
    def __init__(self, parquet_file):
        """
        Args:
            parquet_file (str): Path to the Parquet file containing the dataset.
                                The dataset should have two columns: 'bytes' (image data) and 'label'.
        """
        data = pd.read_parquet(parquet_file).values

        self.image_bytes_list = [
            entry[0]["bytes"] if isinstance(entry[0], dict) else entry[0]
            for entry in data
        ]
        self.class_list = [entry[1] for entry in data]

        self.transform = transforms.Compose(
            [
                transforms.RandomHorizontalFlip(),
                transforms.RandomRotation(15),
                transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2),
                transforms.ToTensor(),
                transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
            ]
        )

    def __len__(self):
        return len(self.image_bytes_list)

    def __getitem__(self, data_id):
        """
        Fetches the image and label for a given index.
        """
        image_bytes = self.image_bytes_list[data_id]
        image_class = self.class_list[data_id]

        image = Image.open(io.BytesIO(image_bytes)).convert("RGB")
        image_tensor = self.transform(image)

        return image_class, image_tensor

# %%
train_dataset = CancerDataset("/content/balanced_skin_cancer_dataset_train_2.parquet")
train_dataloader = DataLoader(train_dataset, batch_size=128, shuffle=True)

val_ratio = 0.125
val_size = int(len(train_dataset) * val_ratio)
train_size = len(train_dataset) - val_size
train_subset, val_subset = random_split(train_dataset, [train_size, val_size])
val_dataloader = DataLoader(val_subset, batch_size=128, shuffle=False)

test_dataset = CancerDataset("/content/balanced_skin_cancer_dataset_test.parquet")
test_dataloader = DataLoader(test_dataset, batch_size=256, shuffle=False)

# %%
_, images = next(iter(train_dataloader))
images = images.numpy()

num_rows = 2
num_columns = 10

figure, axis_array = plt.subplots(
    num_rows, num_columns, figsize=(num_columns * 1.5, num_rows * 1.5)
)
figure.suptitle("Training Data Samples")

im_id = 0
for row_id in range(num_rows):
    for column_id in range(num_columns):
        # The channel dimension of the image is moved to the last index
        # to make the shape of the image compatible with Matplotlib
        image = images[im_id].transpose(1, 2, 0)
        # Value range is mapped from [-1,1] to [0,1]
        image = (image + 1) / 2
        if num_rows == 1:
            current_axis = axis_array[column_id]
        else:
            current_axis = axis_array[row_id, column_id]
        current_axis.axis("off")
        current_axis.imshow(image)
        im_id += 1

# %% [markdown]
# ##**Constructing a Classifier Network**

# %%
class CancerClassifier(nn.Module):
    def __init__(self):
        super(CancerClassifier, self).__init__()

        self.conv_block_1 = nn.Sequential(
            nn.Conv2d(in_channels=3, out_channels=16, kernel_size=3, padding=1),
            nn.BatchNorm2d(16),
            nn.LeakyReLU(0.1),
            nn.MaxPool2d(kernel_size=2, stride=2),  # Output: 16x112x112
        )

        self.conv_block_2 = nn.Sequential(
            nn.Conv2d(in_channels=16, out_channels=32, kernel_size=3, padding=1),
            nn.BatchNorm2d(32),
            nn.LeakyReLU(0.1),
            nn.MaxPool2d(kernel_size=2, stride=2),  # Output: 32x56x56
        )

        self.conv_block_3 = nn.Sequential(
            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.LeakyReLU(0.1),
            nn.MaxPool2d(kernel_size=2, stride=2),  # Output: 64x28x28
        )

        self.conv_block_4 = nn.Sequential(
            nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128),
            nn.LeakyReLU(0.1),
            nn.MaxPool2d(kernel_size=2, stride=2),  # Output: 128x14x14
        )

        self.flatten = nn.Flatten()

        self.fc_layers = nn.Sequential(
            nn.Flatten(),
            nn.Linear(in_features=25088, out_features=64),
            nn.LeakyReLU(0.1),
            nn.Linear(in_features=64, out_features=8),
        )

    def forward(self, x):
        x = self.conv_block_1(x)
        x = self.conv_block_2(x)
        x = self.conv_block_3(x)
        x = self.conv_block_4(x)
        x = self.flatten(x)
        x = self.fc_layers(x)

        return x

# %% [markdown]
# ##**Implementing the Training Loop**

# %%
loss_func = nn.CrossEntropyLoss()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = CancerClassifier().to(device)
optimizer = Adam(model.parameters(), lr=2e-4)
scheduler = ReduceLROnPlateau(optimizer, mode="min", factor=0.5, patience=3)

best_val_loss = float("inf")
patience_counter = 0
patience_limit = 8

# %% [markdown]
# ##**Evaluating the Model**

# %%
def display_evaluation_metrics():
    model.eval()

    pred_class_list = []
    gt_class_list = []

    with torch.no_grad():
        for batch_image_class, batch_image_tensor in test_dataloader:
            if torch.cuda.is_available():
                batch_image_tensor = batch_image_tensor.cuda()
                batch_image_class = batch_image_class.cuda()

            batch_outputs = model(batch_image_tensor)

            batch_image_class = batch_image_class.cpu().numpy()
            batch_outputs = batch_outputs.cpu().numpy()
            pred_classes = np.argmax(batch_outputs, axis=1)

            pred_class_list.extend(pred_classes)
            gt_class_list.extend(batch_image_class)

    accuracy = accuracy_score(gt_class_list, pred_class_list)
    print(f"Accuracy: {accuracy:.4f}")

    print(classification_report(gt_class_list, pred_class_list))

# %% [markdown]
# ##**Confusion Metrics**

# %%
def confusion_metrics():
    cm = confusion_matrix(gt_class_list, pred_class_list)

    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.title("Confusion Matrix")
    plt.show()

# %%
num_batches = len(train_dataloader)
num_val_batches = len(val_dataloader)
num_epochs = 400

train_losses = []
val_losses = []

for epoch in range(num_epochs):
    model.train()
    running_train_loss = 0.0
    for batch_image_class, batch_image_tensor in train_dataloader:
        batch_image_tensor, batch_image_class = batch_image_tensor.to(
            device
        ), batch_image_class.to(device)

        optimizer.zero_grad()
        outputs = model(batch_image_tensor)
        loss = loss_func(outputs, batch_image_class)
        loss.backward()

        nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()

        running_train_loss += loss.item()

    avg_train_loss = running_train_loss / num_batches
    train_losses.append(avg_train_loss)

    model.eval()
    running_val_loss = 0.0
    with torch.no_grad():
        for val_image_class, val_image_tensor in val_dataloader:
            val_image_tensor, val_image_class = val_image_tensor.to(
                device
            ), val_image_class.to(device)
            val_outputs = model(val_image_tensor)
            val_loss = loss_func(val_outputs, val_image_class)
            running_val_loss += val_loss.item()

    avg_val_loss = running_val_loss / num_val_batches
    val_losses.append(avg_val_loss)

    scheduler.step(avg_val_loss)

    current_lr = scheduler.get_last_lr()[0]
    print(
        f"Epoch {epoch+1}/{num_epochs} - Train Loss: {avg_train_loss:.4f} - Val Loss: {avg_val_loss:.4f} - LR: {current_lr:.6f}"
    )

    if epoch % 10 == 0:
        display_evaluation_metrics()
        confusion_metrics()

    # Early stopping rule
    if avg_val_loss < best_val_loss:
        best_val_loss = avg_val_loss
        patience_counter = 0
    else:
        patience_counter += 1
        print(f"No improvement for {patience_counter} epochs.")

    if patience_counter >= patience_limit:
        num_epochs = epoch
        print("Early stopping triggered. Terminating training.")
        break
# Out:
# Epoch 1/400 - Train Loss: 1.6964 - Val Loss: 1.5053 - LR: 0.000200
# Epoch 2/400 - Train Loss: 1.4576 - Val Loss: 1.3984 - LR: 0.000200
# Epoch 3/400 - Train Loss: 1.3672 - Val Loss: 1.3362 - LR: 0.000200
# Epoch 4/400 - Train Loss: 1.3023 - Val Loss: 1.2706 - LR: 0.000200
# Epoch 5/400 - Train Loss: 1.2633 - Val Loss: 1.3061 - LR: 0.000200
# No improvement for 1 epochs.
# Epoch 6/400 - Train Loss: 1.2069 - Val Loss: 1.2572 - LR: 0.000200
# Epoch 7/400 - Train Loss: 1.1759 - Val Loss: 1.1660 - LR: 0.000200
# Epoch 8/400 - Train Loss: 1.1297 - Val Loss: 1.1413 - LR: 0.000200
# Epoch 9/400 - Train Loss: 1.1112 - Val Loss: 1.1023 - LR: 0.000200
# Epoch 10/400 - Train Loss: 1.0838 - Val Loss: 1.1020 - LR: 0.000200
# Epoch 11/400 - Train Loss: 1.0524 - Val Loss: 1.0433 - LR: 0.000200
# Epoch 12/400 - Train Loss: 1.0367 - Val Loss: 1.0497 - LR: 0.000200
# No improvement for 1 epochs.
# Epoch 13/400 - Train Loss: 1.0142 - Val Loss: 1.0727 - LR: 0.000200
# No improvement for 2 epochs.
# Epoch 14/400 - Train Loss: 1.0059 - Val Loss: 0.9857 - LR: 0.000200
# Epoch 15/400 - Train Loss: 0.9717 - Val Loss: 0.9723 - LR: 0.000200
# Epoch 16/400 - Train Loss: 0.9598 - Val Loss: 0.9391 - LR: 0.000200
# Epoch 17/400 - Train Loss: 0.9388 - Val Loss: 0.9206 - LR: 0.000200
# Epoch 18/400 - Train Loss: 0.9206 - Val Loss: 0.8981 - LR: 0.000200
# Epoch 19/400 - Train Loss: 0.9062 - Val Loss: 0.8927 - LR: 0.000200
# Epoch 20/400 - Train Loss: 0.8885 - Val Loss: 0.9052 - LR: 0.000200
# No improvement for 1 epochs.
# Epoch 21/400 - Train Loss: 0.8859 - Val Loss: 0.9896 - LR: 0.000200
# No improvement for 2 epochs.
# Epoch 22/400 - Train Loss: 0.8702 - Val Loss: 0.8508 - LR: 0.000200
# Epoch 23/400 - Train Loss: 0.8493 - Val Loss: 0.8439 - LR: 0.000200
# Epoch 24/400 - Train Loss: 0.8345 - Val Loss: 0.8732 - LR: 0.000200
# No improvement for 1 epochs.
# Epoch 25/400 - Train Loss: 0.8198 - Val Loss: 0.7919 - LR: 0.000200
# Epoch 26/400 - Train Loss: 0.8177 - Val Loss: 0.7994 - LR: 0.000200
# No improvement for 1 epochs.
# Epoch 27/400 - Train Loss: 0.7979 - Val Loss: 0.7892 - LR: 0.000200
# Epoch 28/400 - Train Loss: 0.7818 - Val Loss: 0.7595 - LR: 0.000200
# Epoch 29/400 - Train Loss: 0.7728 - Val Loss: 0.7494 - LR: 0.000200
# Epoch 30/400 - Train Loss: 0.7570 - Val Loss: 0.7497 - LR: 0.000200
# No improvement for 1 epochs.
# Epoch 31/400 - Train Loss: 0.7518 - Val Loss: 0.7802 - LR: 0.000200
# No improvement for 2 epochs.
# Epoch 32/400 - Train Loss: 0.7303 - Val Loss: 0.7374 - LR: 0.000200
# Epoch 33/400 - Train Loss: 0.7203 - Val Loss: 0.6836 - LR: 0.000200
# Epoch 34/400 - Train Loss: 0.7115 - Val Loss: 0.7012 - LR: 0.000200
# No improvement for 1 epochs.
# Epoch 35/400 - Train Loss: 0.7000 - Val Loss: 0.6939 - LR: 0.000200
# No improvement for 2 epochs.
# Epoch 36/400 - Train Loss: 0.6963 - Val Loss: 0.7125 - LR: 0.000200
# No improvement for 3 epochs.
# Epoch 37/400 - Train Loss: 0.6787 - Val Loss: 0.6654 - LR: 0.000200
# Epoch 38/400 - Train Loss: 0.6748 - Val Loss: 0.7526 - LR: 0.000200
# No improvement for 1 epochs.
# Epoch 39/400 - Train Loss: 0.6596 - Val Loss: 0.6341 - LR: 0.000200
# Epoch 40/400 - Train Loss: 0.6496 - Val Loss: 0.6568 - LR: 0.000200
# No improvement for 1 epochs.
# Epoch 41/400 - Train Loss: 0.6313 - Val Loss: 0.6411 - LR: 0.000200
# No improvement for 2 epochs.
# Epoch 42/400 - Train Loss: 0.6437 - Val Loss: 0.5746 - LR: 0.000200
# Epoch 43/400 - Train Loss: 0.6133 - Val Loss: 0.5932 - LR: 0.000200
# No improvement for 1 epochs.
# Epoch 44/400 - Train Loss: 0.6068 - Val Loss: 0.6013 - LR: 0.000200
# No improvement for 2 epochs.
# Epoch 45/400 - Train Loss: 0.5977 - Val Loss: 0.5840 - LR: 0.000200
# No improvement for 3 epochs.
# Epoch 46/400 - Train Loss: 0.5983 - Val Loss: 0.5818 - LR: 0.000100
# No improvement for 4 epochs.
# Epoch 47/400 - Train Loss: 0.5284 - Val Loss: 0.5251 - LR: 0.000100
# Epoch 48/400 - Train Loss: 0.5182 - Val Loss: 0.4890 - LR: 0.000100
# Epoch 49/400 - Train Loss: 0.5045 - Val Loss: 0.5070 - LR: 0.000100
# No improvement for 1 epochs.
# Epoch 50/400 - Train Loss: 0.4996 - Val Loss: 0.4910 - LR: 0.000100
# No improvement for 2 epochs.
# Epoch 51/400 - Train Loss: 0.4890 - Val Loss: 0.4964 - LR: 0.000100
# No improvement for 3 epochs.
# Epoch 52/400 - Train Loss: 0.4880 - Val Loss: 0.4735 - LR: 0.000100
# Epoch 53/400 - Train Loss: 0.4831 - Val Loss: 0.4615 - LR: 0.000100
# Epoch 54/400 - Train Loss: 0.4757 - Val Loss: 0.4456 - LR: 0.000100
# Epoch 55/400 - Train Loss: 0.4667 - Val Loss: 0.4449 - LR: 0.000100
# Epoch 56/400 - Train Loss: 0.4701 - Val Loss: 0.4651 - LR: 0.000100
# No improvement for 1 epochs.
# Epoch 57/400 - Train Loss: 0.4561 - Val Loss: 0.4468 - LR: 0.000100
# No improvement for 2 epochs.
# Epoch 58/400 - Train Loss: 0.4532 - Val Loss: 0.4530 - LR: 0.000100
# No improvement for 3 epochs.
# Epoch 59/400 - Train Loss: 0.4479 - Val Loss: 0.4318 - LR: 0.000100
# Epoch 60/400 - Train Loss: 0.4353 - Val Loss: 0.4250 - LR: 0.000100
# Epoch 61/400 - Train Loss: 0.4390 - Val Loss: 0.4381 - LR: 0.000100
# No improvement for 1 epochs.
# Epoch 62/400 - Train Loss: 0.4280 - Val Loss: 0.3994 - LR: 0.000100
# Epoch 63/400 - Train Loss: 0.4283 - Val Loss: 0.4281 - LR: 0.000100
# No improvement for 1 epochs.
# Epoch 64/400 - Train Loss: 0.4176 - Val Loss: 0.4348 - LR: 0.000100
# No improvement for 2 epochs.
# Epoch 65/400 - Train Loss: 0.4155 - Val Loss: 0.4134 - LR: 0.000100
# No improvement for 3 epochs.
# Epoch 66/400 - Train Loss: 0.4106 - Val Loss: 0.3846 - LR: 0.000100
# Epoch 67/400 - Train Loss: 0.4045 - Val Loss: 0.3822 - LR: 0.000100
# Epoch 68/400 - Train Loss: 0.4001 - Val Loss: 0.3820 - LR: 0.000100
# Epoch 69/400 - Train Loss: 0.3962 - Val Loss: 0.3818 - LR: 0.000100
# Epoch 70/400 - Train Loss: 0.3850 - Val Loss: 0.3473 - LR: 0.000100
# Epoch 71/400 - Train Loss: 0.3786 - Val Loss: 0.3698 - LR: 0.000100
# No improvement for 1 epochs.
# Epoch 72/400 - Train Loss: 0.3828 - Val Loss: 0.3664 - LR: 0.000100
# No improvement for 2 epochs.
# Epoch 73/400 - Train Loss: 0.3816 - Val Loss: 0.3372 - LR: 0.000100
# Epoch 74/400 - Train Loss: 0.3727 - Val Loss: 0.3486 - LR: 0.000100
# No improvement for 1 epochs.
# Epoch 75/400 - Train Loss: 0.3734 - Val Loss: 0.3666 - LR: 0.000100
# No improvement for 2 epochs.
# Epoch 76/400 - Train Loss: 0.3713 - Val Loss: 0.3389 - LR: 0.000100
# No improvement for 3 epochs.
# Epoch 77/400 - Train Loss: 0.3633 - Val Loss: 0.3389 - LR: 0.000050
# No improvement for 4 epochs.
# Epoch 78/400 - Train Loss: 0.3246 - Val Loss: 0.2993 - LR: 0.000050
# Epoch 79/400 - Train Loss: 0.3239 - Val Loss: 0.2972 - LR: 0.000050
# Epoch 80/400 - Train Loss: 0.3165 - Val Loss: 0.3146 - LR: 0.000050
# No improvement for 1 epochs.
# Epoch 81/400 - Train Loss: 0.3234 - Val Loss: 0.3112 - LR: 0.000050
# No improvement for 2 epochs.
# Epoch 82/400 - Train Loss: 0.3122 - Val Loss: 0.2806 - LR: 0.000050
# Epoch 83/400 - Train Loss: 0.3015 - Val Loss: 0.2830 - LR: 0.000050
# No improvement for 1 epochs.
# Epoch 84/400 - Train Loss: 0.3118 - Val Loss: 0.2904 - LR: 0.000050
# No improvement for 2 epochs.
# Epoch 85/400 - Train Loss: 0.3064 - Val Loss: 0.2955 - LR: 0.000050
# No improvement for 3 epochs.
# Epoch 86/400 - Train Loss: 0.3058 - Val Loss: 0.2782 - LR: 0.000050
# Epoch 87/400 - Train Loss: 0.3054 - Val Loss: 0.2820 - LR: 0.000050
# No improvement for 1 epochs.
# Epoch 88/400 - Train Loss: 0.2899 - Val Loss: 0.2591 - LR: 0.000050
# Epoch 89/400 - Train Loss: 0.2925 - Val Loss: 0.2883 - LR: 0.000050
# No improvement for 1 epochs.
# Epoch 90/400 - Train Loss: 0.2839 - Val Loss: 0.2683 - LR: 0.000050
# No improvement for 2 epochs.
# Epoch 91/400 - Train Loss: 0.2850 - Val Loss: 0.2506 - LR: 0.000050
# Epoch 92/400 - Train Loss: 0.2827 - Val Loss: 0.2660 - LR: 0.000050
# No improvement for 1 epochs.
# Epoch 93/400 - Train Loss: 0.2793 - Val Loss: 0.2723 - LR: 0.000050
# No improvement for 2 epochs.
# Epoch 94/400 - Train Loss: 0.2830 - Val Loss: 0.2592 - LR: 0.000050
# No improvement for 3 epochs.
# Epoch 95/400 - Train Loss: 0.2737 - Val Loss: 0.2697 - LR: 0.000025
# No improvement for 4 epochs.
# Epoch 96/400 - Train Loss: 0.2577 - Val Loss: 0.2403 - LR: 0.000025
# Epoch 97/400 - Train Loss: 0.2530 - Val Loss: 0.2455 - LR: 0.000025
# No improvement for 1 epochs.
# Epoch 98/400 - Train Loss: 0.2554 - Val Loss: 0.2483 - LR: 0.000025
# No improvement for 2 epochs.
# Epoch 99/400 - Train Loss: 0.2537 - Val Loss: 0.2402 - LR: 0.000025
# Epoch 100/400 - Train Loss: 0.2550 - Val Loss: 0.2295 - LR: 0.000025
# Epoch 101/400 - Train Loss: 0.2540 - Val Loss: 0.2311 - LR: 0.000025
# No improvement for 1 epochs.
# Epoch 102/400 - Train Loss: 0.2549 - Val Loss: 0.2265 - LR: 0.000025
# Epoch 103/400 - Train Loss: 0.2531 - Val Loss: 0.2408 - LR: 0.000025
# No improvement for 1 epochs.
# Epoch 104/400 - Train Loss: 0.2464 - Val Loss: 0.2279 - LR: 0.000025
# No improvement for 2 epochs.
# Epoch 105/400 - Train Loss: 0.2462 - Val Loss: 0.2363 - LR: 0.000025
# No improvement for 3 epochs.
# Epoch 106/400 - Train Loss: 0.2405 - Val Loss: 0.2313 - LR: 0.000013
# No improvement for 4 epochs.
# Epoch 107/400 - Train Loss: 0.2326 - Val Loss: 0.2342 - LR: 0.000013
# No improvement for 5 epochs.
# Epoch 108/400 - Train Loss: 0.2329 - Val Loss: 0.2282 - LR: 0.000013
# No improvement for 6 epochs.
# Epoch 109/400 - Train Loss: 0.2338 - Val Loss: 0.2153 - LR: 0.000013
# Epoch 110/400 - Train Loss: 0.2348 - Val Loss: 0.2282 - LR: 0.000013
# No improvement for 1 epochs.
# Epoch 111/400 - Train Loss: 0.2376 - Val Loss: 0.2245 - LR: 0.000013
# No improvement for 2 epochs.
# Epoch 112/400 - Train Loss: 0.2300 - Val Loss: 0.2087 - LR: 0.000013
# Epoch 113/400 - Train Loss: 0.2314 - Val Loss: 0.2064 - LR: 0.000013
# Epoch 114/400 - Train Loss: 0.2318 - Val Loss: 0.2211 - LR: 0.000013
# No improvement for 1 epochs.
# Epoch 115/400 - Train Loss: 0.2331 - Val Loss: 0.2068 - LR: 0.000013
# No improvement for 2 epochs.
# Epoch 116/400 - Train Loss: 0.2323 - Val Loss: 0.2122 - LR: 0.000013
# No improvement for 3 epochs.
# Epoch 117/400 - Train Loss: 0.2264 - Val Loss: 0.2189 - LR: 0.000006
# No improvement for 4 epochs.
# Epoch 118/400 - Train Loss: 0.2231 - Val Loss: 0.2095 - LR: 0.000006
# No improvement for 5 epochs.
# Epoch 119/400 - Train Loss: 0.2276 - Val Loss: 0.2142 - LR: 0.000006
# No improvement for 6 epochs.
# Epoch 120/400 - Train Loss: 0.2254 - Val Loss: 0.2201 - LR: 0.000006
# No improvement for 7 epochs.
# Epoch 121/400 - Train Loss: 0.2188 - Val Loss: 0.2142 - LR: 0.000003
# No improvement for 8 epochs.
# Early stopping triggered. Terminating training.

# %% [markdown]
# ##**Plotting the Training Loss Curves**

# %%
plt.plot(
    range(1, num_epochs + 1),
    train_losses,
    label="Train Loss",
    color="tab:blue",
    linewidth=2,
)
plt.plot(
    range(1, num_epochs + 1),
    val_losses,
    label="Validation Loss",
    color="tab:orange",
    linewidth=2,
)
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training and Validation Loss per Epoch")
plt.legend()
plt.grid()
plt.show()
